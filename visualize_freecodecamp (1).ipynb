# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
apples = [0.895,0.91,0.919,0.926,0.929,0.931]

# %%
plt.plot(apples);

# %%
sns.set_style('whitegrid')

# %%
years = [2010,2011,2012,2013,2014,2015]
apples = [0.895,0.91,0.919,0.926,0.929,0.931]
oranges = [0.962,0.941,0.930,0.923,0.918,0.908]
plt.plot(years, apples, marker='o')
plt.plot(years, oranges, marker='x', ms=10)
plt.xlabel('Year')
plt.ylabel('Yield')
plt.legend(['Apples', 'Oranges'])

# %%
for x in range(2000 , 2012):
  print(x)

# %%
iris = sns.load_dataset('iris')

# %%
plt.plot(iris.sepal_length, iris.sepal_width)

# %%
sns.scatterplot(iris.sepal_length, iris.sepal_width, hue=iris.species, s=100)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
